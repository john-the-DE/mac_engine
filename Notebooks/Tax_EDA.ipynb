# %%
import os
from glob import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
active_dir = '/Users/johnnycortez/Documents/springboard/data'
os.chdir(active_dir)

# %%
os.listdir()
# Out:
# ['ZIP-COUNTY-FIPS.txt',
#  'tax_data_2018.txt',
#  'Headers_2017.docx',
#  'Headers_2016.docx',
#  'Headers_2015.docx',
#  'Headers_2018.docx',
#  'Headers_2014.docx',
#  'tax_data_2015.txt',
#  'tax_data_2014.txt',
#  'tax_data_2016.txt',
#  'tax_data_2017.txt']

# %%
year_2014 = pd.read_csv('tax_data_2014.txt')

# %%
header_2014 = pd.read_csv('header_2014.csv')
header_2014
# Out:
#     VARIABLE NAME                                        DESCRIPTION  \
# 0       STATEFIPS  The State Federal Information Processing Syste...
# 1           STATE             The State associated with the ZIP code
# 2         ZIPCODE                                   5-digit Zip code
# 3        AGI_STUB                      Size of adjusted gross income
# 4              N1                                  Number of returns
# ..            ...                                                ...
# 124        A11901            Tax due at time of filing amount [10]
# 125        N11902       Number of returns with overpayments refunded
# 126        A11902                Overpayments refunded amount [11]
# 127           NaN                                                NaN
# 128           NaN                                                NaN
#
#      Unnamed: 2                               VALUE/LINE REFERENCE  \
# 0           NaN                                              01-56
# ...

# %%
header_2014_definitions = header_2014[['VARIABLE NAME', 'DESCRIPTION']]

# %%
header_2014_definitions
# Out:
#     VARIABLE NAME                                        DESCRIPTION
# 0       STATEFIPS  The State Federal Information Processing Syste...
# 1           STATE             The State associated with the ZIP code
# 2         ZIPCODE                                   5-digit Zip code
# 3        AGI_STUB                      Size of adjusted gross income
# 4              N1                                  Number of returns
# ..            ...                                                ...
# 124        A11901            Tax due at time of filing amount [10]
# 125        N11902       Number of returns with overpayments refunded
# 126        A11902                Overpayments refunded amount [11]
# 127           NaN                                                NaN
# 128           NaN                                                NaN
#
# [129 rows x 2 columns]
